# %%
import pandas as pd
import numpy as np
df = pd.read_csv('WMT.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
float_columns = ['Open', 'High', 'Low', 'Close', 'Adj Close']
df[float_columns] = df[float_columns].astype(float)
df['Volume'] = df['Volume'].astype(int)

# %%
print(df.isnull().sum())
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df['MA20'] = df['Close'].rolling(window=20).mean()

# %%
df.sort_index(inplace=True)

print(df.head())
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2000-01-03  22.791668  23.000000  21.833332  22.270832  14.469358  25109700
# 2000-01-04  21.833332  21.937500  21.395832  21.437500  13.927947  20235300
# 2000-01-05  21.291668  21.458332  20.729168  21.000000  13.643703  21056100
# 2000-01-06  21.000000  21.520832  20.895832  21.229168  13.792585  19633500
# 2000-01-07  21.500000  22.979168  21.500000  22.833332  14.834813  23930700
#
#             MA20
# Date
# 2000-01-03   NaN
# 2000-01-04   NaN
# 2000-01-05   NaN
# 2000-01-06   NaN
# 2000-01-07   NaN

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
df = df.drop('MA20', axis=1)
data = df[['Adj Close', 'Volume']].values

# %%
df.dropna(inplace=True)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
def create_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), :])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

sequence_length = 300  # You can adjust this
X, y = create_sequences(scaled_data, sequence_length)

# %%
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %%
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(sequence_length, 2)),
    Dropout(0.2),
    LSTM(50, return_sequences=False),
    Dropout(0.2),
    Dense(25),
    Dense(1)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mean_squared_error')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.1,
    shuffle=False,
    callbacks=[early_stopping],
    verbose=2
)
# Out:
# Epoch 1/50
# 131/131 - 6s - 48ms/step - loss: 8.6898e-04 - val_loss: 0.0091
# Epoch 2/50
# 131/131 - 4s - 34ms/step - loss: 0.0012 - val_loss: 0.0052
# Epoch 3/50
# 131/131 - 3s - 20ms/step - loss: 5.7922e-04 - val_loss: 0.0018
# Epoch 4/50
# 131/131 - 5s - 39ms/step - loss: 3.4289e-04 - val_loss: 3.5903e-04
# Epoch 5/50
# 131/131 - 2s - 19ms/step - loss: 2.4281e-04 - val_loss: 2.9301e-04
# Epoch 6/50
# 131/131 - 2s - 19ms/step - loss: 2.0408e-04 - val_loss: 3.0591e-04
# Epoch 7/50
# 131/131 - 3s - 24ms/step - loss: 1.8392e-04 - val_loss: 2.9419e-04
# Epoch 8/50
# 131/131 - 5s - 36ms/step - loss: 1.7583e-04 - val_loss: 2.8514e-04
# Epoch 9/50
# 131/131 - 5s - 39ms/step - loss: 1.6393e-04 - val_loss: 3.2919e-04
# Epoch 10/50
# 131/131 - 3s - 25ms/step - loss: 1.6502e-04 - val_loss: 3.0395e-04
# Epoch 11/50
# 131/131 - 3s - 20ms/step - loss: 1.6310e-04 - val_loss: 2.7468e-04
# Epoch 12/50
# 131/131 - 5s - 39ms/step - loss: 1.5810e-04 - val_loss: 2.7900e-04
# Epoch 13/50
# 131/131 - 6s - 45ms/step - loss: 1.4953e-04 - val_loss: 2.6321e-04
# Epoch 14/50
# 131/131 - 2s - 19ms/step - loss: 1.4720e-04 - val_loss: 2.5859e-04
# Epoch 15/50
# 131/131 - 2s - 19ms/step - loss: 1.3791e-04 - val_loss: 2.4741e-04
# Epoch 16/50
# 131/131 - 3s - 19ms/step - loss: 1.4668e-04 - val_loss: 2.5707e-04
# Epoch 17/50
# 131/131 - 3s - 21ms/step - loss: 1.3866e-04 - val_loss: 3.1819e-04
# Epoch 18/50
# 131/131 - 5s - 38ms/step - loss: 1.3239e-04 - val_loss: 2.4429e-04
# Epoch 19/50
# 131/131 - 5s - 39ms/step - loss: 1.2185e-04 - val_loss: 2.4659e-04
# Epoch 20/50
# 131/131 - 5s - 39ms/step - loss: 1.3716e-04 - val_loss: 2.4655e-04
# Epoch 21/50
# 131/131 - 2s - 19ms/step - loss: 1.1672e-04 - val_loss: 2.3571e-04
# Epoch 22/50
# 131/131 - 2s - 19ms/step - loss: 1.2451e-04 - val_loss: 2.3566e-04
# Epoch 23/50
# 131/131 - 2s - 19ms/step - loss: 1.1721e-04 - val_loss: 2.3817e-04
# Epoch 24/50
# 131/131 - 3s - 25ms/step - loss: 1.2010e-04 - val_loss: 2.3827e-04
# Epoch 25/50
# 131/131 - 4s - 34ms/step - loss: 1.2810e-04 - val_loss: 2.6022e-04
# Epoch 26/50
# 131/131 - 5s - 41ms/step - loss: 1.1970e-04 - val_loss: 2.3007e-04
# Epoch 27/50
# 131/131 - 5s - 37ms/step - loss: 1.1616e-04 - val_loss: 2.2847e-04
# Epoch 28/50
# 131/131 - 5s - 38ms/step - loss: 1.1387e-04 - val_loss: 2.2603e-04
# Epoch 29/50
# 131/131 - 5s - 39ms/step - loss: 1.1883e-04 - val_loss: 2.3345e-04
# Epoch 30/50
# 131/131 - 2s - 19ms/step - loss: 1.1329e-04 - val_loss: 2.4295e-04
# Epoch 31/50
# 131/131 - 3s - 20ms/step - loss: 1.1368e-04 - val_loss: 2.1704e-04
# Epoch 32/50
# 131/131 - 3s - 19ms/step - loss: 1.0266e-04 - val_loss: 2.1565e-04
# Epoch 33/50
# 131/131 - 3s - 26ms/step - loss: 1.0953e-04 - val_loss: 2.2223e-04
# Epoch 34/50
# 131/131 - 4s - 32ms/step - loss: 1.1553e-04 - val_loss: 2.1582e-04
# Epoch 35/50
# 131/131 - 3s - 19ms/step - loss: 1.1009e-04 - val_loss: 2.1495e-04
# Epoch 36/50
# 131/131 - 3s - 19ms/step - loss: 1.0717e-04 - val_loss: 2.1250e-04
# Epoch 37/50
# 131/131 - 3s - 26ms/step - loss: 1.0379e-04 - val_loss: 2.1672e-04
# Epoch 38/50
# 131/131 - 2s - 19ms/step - loss: 1.0206e-04 - val_loss: 2.0932e-04
# Epoch 39/50
# 131/131 - 2s - 19ms/step - loss: 9.7393e-05 - val_loss: 2.0533e-04
# Epoch 40/50
# 131/131 - 3s - 20ms/step - loss: 1.0302e-04 - val_loss: 2.0351e-04
# Epoch 41/50
# 131/131 - 2s - 19ms/step - loss: 9.8631e-05 - val_loss: 2.1105e-04
# Epoch 42/50
# 131/131 - 4s - 32ms/step - loss: 1.0394e-04 - val_loss: 2.0705e-04
# Epoch 43/50
# 131/131 - 3s - 26ms/step - loss: 1.0927e-04 - val_loss: 2.1114e-04
# Epoch 44/50
# 131/131 - 3s - 19ms/step - loss: 1.0122e-04 - val_loss: 2.2239e-04
# Epoch 45/50
# 131/131 - 3s - 19ms/step - loss: 1.1616e-04 - val_loss: 2.0852e-04
# Epoch 46/50
# 131/131 - 3s - 25ms/step - loss: 9.6860e-05 - val_loss: 1.9989e-04
# Epoch 47/50
# 131/131 - 3s - 20ms/step - loss: 9.6902e-05 - val_loss: 1.9636e-04
# Epoch 48/50
# 131/131 - 2s - 18ms/step - loss: 9.4907e-05 - val_loss: 1.9519e-04
# Epoch 49/50
# 131/131 - 3s - 20ms/step - loss: 9.1262e-05 - val_loss: 2.1255e-04
# Epoch 50/50
# 131/131 - 2s - 19ms/step - loss: 9.5509e-05 - val_loss: 2.0483e-04

# %%
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0405e-04
# Test Loss: 0.0005401704693213105

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(np.concatenate((predictions, np.zeros((len(predictions), 1))), axis=1))[:, 0]
actual = scaler.inverse_transform(np.concatenate((y_test.reshape(-1, 1), np.zeros((len(y_test), 1))), axis=1))[:, 0]
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %%
rmse = np.sqrt(np.mean((predictions - actual) ** 2))
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Root Mean Squared Error: 1.209747305846533

# %%
max_error = np.max(np.abs(predictions - actual))
print(f"Maximum Error: {max_error}")
# Out:
# Maximum Error: 7.648844410486703

# %%
from sklearn.metrics import r2_score
r2 = r2_score(actual, predictions)
print(f"R-squared: {r2}")
# Out:
# R-squared: 0.9568847989595195

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
plt.figure(figsize=(12, 6))
plt.plot(actual, label='Actual')
plt.plot(predictions, label='Predicted')
plt.title('Actual vs Predicted Stock Prices')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
